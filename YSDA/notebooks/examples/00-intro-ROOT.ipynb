# %%
import ROOT
from cern_utils import rootnotes
c1 = rootnotes.default_canvas()
fun1 = ROOT.TF1( 'fun1', 'abs(sin(x)/x)', 0, 10)
c1.SetGridx()
c1.SetGridy()
fun1.Draw()
c1
# Out:
# <ROOT.TCanvas object ("icanvas") at 0x4295860>

# %%
F = ROOT.TFile("ToyMC/toyMC_bck_mass.root")

# %%
T = F.Get("Tau23Mu")

# %%
T.Draw("min_DOCA")
c1
# Out:
# <ROOT.TCanvas object ("icanvas") at 0x4295860>

# %%
h1 =  ROOT.TH1F("h1","hist from tree",50, -0.25, 0.25)

# %%
T.Draw("min_DOCA>>h1")
c1
# Out:
# <ROOT.TCanvas object ("icanvas") at 0x4295860>
